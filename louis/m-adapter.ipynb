# %%
import pandas as pd
import numpy as np
import msgspec
from pathlib import Path
from pprint import pprint

# encoder = msgspec.json.Encoder()
# decoder = msgspec.json.Decoder()


# from tevatron.retriever.arguments import DataArguments, ModelArguments
# from tevatron.retriever.collator import EncodeCollator
# from tevatron.retriever.dataset import EncodeDataset
# data_args = DataArguments(
#     dataset_name="Tevatron/wikipedia-nq-corpus",
# )

# encode_dataset = EncodeDataset(
#     data_args=data_args,
# )

# %% [markdown]
# ## M-adapter

# %%
# %cd /home/thuy0050/code/matryoshka
from matryoshka import Matryoshka
base_model = Matryoshka(matryoshka_dim=384, adaptor=False)
model = Matryoshka(
    model_name="/home/thuy0050/mg61_scratch2/thuy0050/exp/ts-retriever/models/Tscontriever",
    matryoshka_dim=384,
    adaptor=True,
)
tokenizer = model.tokenizer

sentences = ["sentence"]
inputs = tokenizer(sentences, return_tensors="pt", padding=True, truncation=True)
# print(model)
# Out:
# /home/thuy0050/code/matryoshka

# %%
# %cd /home/thuy0050/code/TS-Retriever/evaluation

from experiment import experiment

embed_model_query = "Tscontriever"
embed_model_doc = "Tscontriever"
query_embed_save_dir = "/home/thuy0050/mg61_scratch2/thuy0050/exp/ts-retriever/models/temp_embed_files/query"
doc_embed_save_dir = "/home/thuy0050/mg61_scratch2/thuy0050/exp/ts-retriever/models/temp_embed_files/docs"

experiment(embed_model_query, embed_model_doc, query_embed_save_dir, str(Path(doc_embed_save_dir) / f"{embed_model_doc}_embed_doc"))
# Out:
# /home/thuy0050/code/TS-Retriever/evaluation
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3244/3244 [00:13<00:00, 240.43it/s]
# +------+-----------+--------+-------+-------+
# |  k   | Precision | Recall |  nDCG |  mAP  |
# +------+-----------+--------+-------+-------+
# |  @1  |   58.63   | 19.92  | 58.63 | 58.63 |
# |  @3  |   44.49   | 40.63  | 53.92 | 46.58 |
# |  @5  |   36.49   |  52.7  | 54.72 | 44.76 |
# | @10  |   25.34   | 69.13  | 60.01 | 47.54 |
# | @20  |   15.72   | 81.52  | 65.18 | 50.83 |
# | @50  |    7.3    | 91.53  | 68.53 | 52.27 |
# | @100 |    3.81   | 94.57  | 69.37 | 52.47 |
# |  @1  |   58.63   | 19.92  | 58.63 | 58.63 |
# |  @3  |   44.49   | 40.63  | 53.92 | 46.58 |
# |  @5  |   36.49   |  52.7  | 54.72 | 44.76 |
# | @10  |   25.34   | 69.13  | 60.01 | 47.54 |
# ...

# %%
from datasets import Dataset

dataset = Dataset.from_file(
    "/home/thuy0050/mg61_scratch2/thuy0050/data/third_work/tevatron/Tevatron___scifact/default/0.0.1/335a81680f0bb1a35c26203db5cbf694f3a09318/scifact-test.arrow"
)

# corpus = Dataset.from_file(
#     "/home/thuy0050/mg61_scratch2/thuy0050/data/third_work/tevatron/Tevatron___scifact-corpus/default/0.0.1/5f84defeb43eba98a4cdf7500076b1c37f69326a/scifact-corpus-train.arrow"
# )

# %%
dataset[0]
# Out:
# {'query_id': '7',
#  'query': '10-20% of people with severe mental disorder receive no treatment in low and middle income countries.',
#  'positive_passages': [],
#  'negative_passages': []}

# %%
from datasets import load_dataset

dataset = load_dataset("LouisDo2108/temporal-nobel-prize", data_files={"qrel": "qrel.txt"}, cache_dir="/home/thuy0050/mg61_scratch2/thuy0050/data/third_work/tevatron")
# Out:
# Generating qrel split: 13110 examples [00:00, 2223416.98 examples/s]

# %%
dataset.cache_files
# Out:
# {'qrel': [{'filename': '/home/thuy0050/mg61_scratch2/thuy0050/.cache/huggingface/datasets/LouisDo2108___temporal-nobel-prize/default-c597d1f6a2570d5b/0.0.0/ac0393e98def4739605a77d3d08c480b8a199980/temporal-nobel-prize-qrel.arrow'}]}
